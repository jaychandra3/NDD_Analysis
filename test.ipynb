# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

pahaw = pd.read_csv('/work/PaHaW_spirals/00008__1_1.csv', header = None)
x = pahaw[0]
y = pahaw[1]
plt.plot(x, y)
plt.title('PaHaW Sample Patient Drawing')
# Out:
# Text(0.5, 1.0, 'PaHaW Sample Patient Drawing')

# %%
pahaw = pd.read_csv('/work/PaHaW_spirals/00008__1_1.csv', header = None)
x = pahaw[0]
y = pahaw[1]

parkinsonhw = pd.read_csv('/work/ParkinsonHW/H_P000-0008.txt', sep = ';', header = None)
static = parkinsonhw[parkinsonhw[6]==0]
x1 = static[0]
y1 = static[1]
plt.figure(figsize = (15, 5))
plt.subplot(2, 4, 1)
plt.plot(x, y)
plt.title('PaHaW Sample Patient Drawing')
plt.subplot(2, 4, 2)
plt.plot(x1, y1)
plt.title('ParkinsonHW Sample Patient Drawing')
# Out:
# Text(0.5, 1.0, 'ParkinsonHW Sample Patient Drawing')

# %%
fig = plt.figure(figsize = (15, 10))
df1 = pd.read_csv('/work/ParkinsonHW/H_p000-0042.txt', sep = ';', header = None)
df_static = df1[df1[6]==0]
x = df_static[0]
y = df_static[1]
plt.subplot(2,2,1)
plt.title("Random Patient #1", fontsize = 20)
plt.plot(x, y)

df1 = pd.read_csv('/work/ParkinsonHW/H_p000-0028.txt', sep = ';', header = None)
df_static = df1[df1[6]==0]
x = df_static[0]
y = df_static[1]
curve = np.array([x, y])
plt.subplot(2,2,2)
plt.title("Random Patient #2", fontsize = 20)
plt.plot(x,y)

df1 = pd.read_csv('/work/ParkinsonHW/C_0001.txt', sep = ';', header = None)
df_static = df1[df1[6]==0]
x = df_static[0]
y = df_static[1]
plt.subplot(2,2,3)
plt.title("Random Control #1", fontsize = 20)
plt.plot(x,y)

df1 = pd.read_csv('/work/ParkinsonHW/C_0001.txt', sep = ';', header = None)
df_static = df1[df1[6]==0]
x = df_static[0]
y = df_static[1]
plt.subplot(2,2,4)
plt.title("Random Control #2", fontsize = 20)
plt.plot(x,y)

# %%
fig = plt.figure(figsize = (15, 10))
df = pd.read_csv('/work/PaHaW_spirals/00005__1_1.csv', header = None)
x = df[0]
y = df[1]
plt.subplot(2,2,1)
plt.title("Random Patient #1", fontsize = 20)
plt.plot(x, y, 'r')

df = pd.read_csv('/work/PaHaW_spirals/00036__1_1.csv', header = None)
x = df[0]
y = df[1]
plt.subplot(2,2,2)
plt.title("Random Patient #2", fontsize = 20)
plt.plot(x,y, 'r')

df = pd.read_csv('/work/PaHaW_spirals/00032__1_1.csv', header = None)
x = df[0]
y = df[1]
plt.subplot(2,2,3)
plt.title("Random Control #1", fontsize = 20)
plt.plot(x,y, 'r')

df = pd.read_csv('/work/PaHaW_spirals/00026__1_1.csv', header = None)
x = df[0]
y = df[1]
plt.subplot(2,2,4)
plt.title("Random Control #2", fontsize = 20)
plt.plot(x,y, 'r')
