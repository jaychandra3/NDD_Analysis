# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting ipynb
#   Downloading ipynb-0.5.1-py3-none-any.whl (6.9 kB)
# Collecting ffmpeg
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
# Collecting Wand
#   Downloading Wand-0.6.5-py2.py3-none-any.whl (138 kB)
# Collecting numba
#   Downloading numba-0.52.0-cp37-cp37m-manylinux2014_x86_64.whl (3.2 MB)
# Collecting fdasrsf
#   Downloading fdasrsf-2.2.2.tar.gz (3.9 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Collecting openpyxl
#   Downloading openpyxl-3.0.6-py2.py3-none-any.whl (242 kB)
# Collecting umap-learn
#   Downloading umap-learn-0.5.1.tar.gz (80 kB)
# Requirement already satisfied: numpy>=1.15 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from numba->-r ./requirements.txt (line 4)) (1.19.5)
# Collecting llvmlite<0.36,>=0.35.0
#   Downloading llvmlite-0.35.0-cp37-cp37m-manylinux2010_x86_64.whl (25.3 MB)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.7/site-packages (from numba->-r ./requirements.txt (line 4)) (47.1.0)
# Collecting patsy
#   Downloading patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from fdasrsf->-r ./requirements.txt (line 5)) (1.15.0)
# Requirement already satisfied: joblib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fdasrsf->-r ./requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: cffi>=1.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from fdasrsf->-r ./requirements.txt (line 5)) (1.14.4)
# Requirement already satisfied: matplotlib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fdasrsf->-r ./requirements.txt (line 5)) (3.3.4)
# Requirement already satisfied: tqdm in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fdasrsf->-r ./requirements.txt (line 5)) (4.56.0)
# Requirement already satisfied: pyparsing in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from fdasrsf->-r ./requirements.txt (line 5)) (2.4.7)
# Collecting Cython
#   Using cached Cython-0.29.21-cp37-cp37m-manylinux1_x86_64.whl (2.0 MB)
# Requirement already satisfied: scipy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fdasrsf->-r ./requirements.txt (line 5)) (1.6.0)
# Collecting jdcal
#   Downloading jdcal-1.4.1-py2.py3-none-any.whl (9.5 kB)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.0.1.tar.gz (8.4 kB)
# Requirement already satisfied: scikit-learn>=0.22 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from umap-learn->-r ./requirements.txt (line 8)) (0.24.1)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.2.tar.gz (1.1 MB)
# Requirement already satisfied: pycparser in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cffi>=1.0.0->fdasrsf->-r ./requirements.txt (line 5)) (2.20)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->fdasrsf->-r ./requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->fdasrsf->-r ./requirements.txt (line 5)) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->fdasrsf->-r ./requirements.txt (line 5)) (8.1.0)
# Requirement already satisfied: python-dateutil>=2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->fdasrsf->-r ./requirements.txt (line 5)) (2.8.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn>=0.22->umap-learn->-r ./requirements.txt (line 8)) (2.1.0)
# Building wheels for collected packages: ffmpeg, fdasrsf, umap-learn, et-xmlfile, pynndescent
#   Building wheel for ffmpeg (setup.py): started
#   Building wheel for ffmpeg (setup.py): finished with status 'done'
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=02ce116103421b7c5e2f0a14976d89326f39a8d161005f08f10eea10fab1fce8
#   Stored in directory: /root/.cache/pip/wheels/64/80/6e/caa3e16deb0267c3cbfd36862058a724144e19fdb9eb03af0f
#   Building wheel for fdasrsf (PEP 517): started
#   Building wheel for fdasrsf (PEP 517): finished with status 'done'
#   Created wheel for fdasrsf: filename=fdasrsf-2.2.2-cp37-cp37m-linux_x86_64.whl size=430694 sha256=848ace83acc976ddc7b1bc29a788b86ebfd24da61a0d6e38a47abceb9418fc6a
#   Stored in directory: /root/.cache/pip/wheels/45/56/6a/24b0a01ed2259c07c9a6202bf6d24c20c4e92dcddf3f2c2d5a
#   Building wheel for umap-learn (setup.py): started
#   Building wheel for umap-learn (setup.py): finished with status 'done'
#   Created wheel for umap-learn: filename=umap_learn-0.5.1-py3-none-any.whl size=76566 sha256=6c3ba87432c3b0014657a2661af9378c6d986634d4c529b54ee10709000c5ddb
#   Stored in directory: /root/.cache/pip/wheels/01/e7/bb/347dc0e510803d7116a13d592b10cc68262da56a8eec4dd72f
#   Building wheel for et-xmlfile (setup.py): started
#   Building wheel for et-xmlfile (setup.py): finished with status 'done'
#   Created wheel for et-xmlfile: filename=et_xmlfile-1.0.1-py3-none-any.whl size=8913 sha256=415e77ba2aa83eff3f6bb42b08cf813a53194cfc9da8a53d036f681d5fd66bda
#   Stored in directory: /root/.cache/pip/wheels/e2/bd/55/048b4fd505716c4c298f42ee02dffd9496bb6d212b266c7f31
#   Building wheel for pynndescent (setup.py): started
#   Building wheel for pynndescent (setup.py): finished with status 'done'
#   Created wheel for pynndescent: filename=pynndescent-0.5.2-py3-none-any.whl size=51347 sha256=841943fa62cd641a5d6a61be5a073bfd34ce915ce0e08ad714edbca746746357
#   Stored in directory: /root/.cache/pip/wheels/62/0b/55/40d651c5a4106ea9ce68d014335a1c7bf059530722c0107b15
# Successfully built ffmpeg fdasrsf umap-learn et-xmlfile pynndescent
# Installing collected packages: ipynb, ffmpeg, Wand, llvmlite, numba, patsy, Cython, fdasrsf, xlrd, jdcal, et-xmlfile, openpyxl, pynndescent, umap-learn
# Successfully installed Cython-0.29.21 Wand-0.6.5 et-xmlfile-1.0.1 fdasrsf-2.2.2 ffmpeg-1.4 ipynb-0.5.1 jdcal-1.4.1 llvmlite-0.35.0 numba-0.52.0 openpyxl-3.0.6 patsy-0.5.1 pynndescent-0.5.2 umap-learn-0.5.1 xlrd-2.0.1
# WARNING: You are using pip version 20.1.1; however, version 21.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=54ea7590-1f30-42ee-b9c1-c929b94e3f2f' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
