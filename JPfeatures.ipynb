# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math as m
import os

# %run features.ipynb

# %%
frame_list1 = []
features_df = add_drawing_csv('/home/jovyan/work/P csv', frame_list1)
features_df = add_drawing_csv('/home/jovyan/work/J csv', frame_list1)
features_df
# Out:
#       Drawing Label  Mean Velocity  Velocity Std  Peak Velocity       NVV  \
# 0    drawing_P2.csv     246.181098    157.712739     514.135324  0.604779
# 1    drawing_P5.csv     291.444143    214.750114     689.256824  0.793849
# 2    drawing_P4.csv     275.813024    170.699315     609.049827  0.718499
# 3    drawing_P3.csv     289.187210    157.791393     528.946122  0.702026
# 4    drawing_P1.csv     302.160935    181.466269     592.144354  0.704032
# 5  drawing_Jay4.csv     344.682563    194.999386     622.263790  0.762595
# 6  drawing_Jay3.csv     340.435061    217.905521     694.067225  0.886732
# 7  drawing_Jay2.csv     392.537762    237.897369     820.392680  0.978632
# 8  drawing_Jay5.csv     256.677582    137.380942     438.168762  0.642943
# 9  drawing_Jay1.csv     361.412124    235.287001     790.441680  0.868590
#
#    NIV  Mean Acceleration  Acceleration Std  Peak Acceleration  NIA  ...  \
# 0    8         148.952472        336.764899        7365.695616  281  ...
# ...
